# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
airlines=pd.read_excel('D:\\PGP IN DATA SCIENCE with careerera\\Files\\Airlines.safety.xlsx')

# %%
airlines.head(5)
# Out:
#    Unnamed: 0                airline  avail_seat_km_per_week  incidents_85_99  \
# 0         NaN             Aer Lingus               320906734                2
# 1         NaN              Aeroflot*              1197672318               76
# 2         NaN  Aerolineas Argentinas               385803648                6
# 3         NaN            Aeromexico*               596871813                3
# 4         NaN             Air Canada              1865253802                2
#
#    fatal_accidents_85_99  fatalities_85_99  incidents_00_14  \
# 0                      0                 0                0
# 1                     14               128                6
# 2                      0                 0                1
# 3                      1                64                5
# 4                      0                 0                2
#
#    fatal_accidents_00_14  fatalities_00_14
# 0                      0                 0
# 1                      1                88
# ...

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              0 non-null      float64
#  1   airline                 56 non-null     object
#  2   avail_seat_km_per_week  56 non-null     int64
#  3   incidents_85_99         56 non-null     int64
#  4   fatal_accidents_85_99   56 non-null     int64
#  5   fatalities_85_99        56 non-null     int64
#  6   incidents_00_14         56 non-null     int64
#  7   fatal_accidents_00_14   56 non-null     int64
#  8   fatalities_00_14        56 non-null     int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 4.1+ KB

# %%
airlines.columns
# Out:
# Index(['Unnamed: 0', 'airline', 'avail_seat_km_per_week', 'incidents_85_99',
#        'fatal_accidents_85_99', 'fatalities_85_99', 'incidents_00_14',
#        'fatal_accidents_00_14', 'fatalities_00_14'],
#       dtype='object')

# %%
airlines.drop('Unnamed: 0',axis=1,inplace=True)

# %%
airlines
# Out:
#                        airline  avail_seat_km_per_week  incidents_85_99  \
# 0                   Aer Lingus               320906734                2
# 1                    Aeroflot*              1197672318               76
# 2        Aerolineas Argentinas               385803648                6
# 3                  Aeromexico*               596871813                3
# 4                   Air Canada              1865253802                2
# 5                   Air France              3004002661               14
# 6                   Air India*               869253552                2
# 7             Air New Zealand*               710174817                3
# 8             Alaska Airlines*               965346773                5
# 9                     Alitalia               698012498                7
# 10          All Nippon Airways              1841234177                3
# 11                   American*              5228357340               21
# ...

# %%
airlines.columns
# Out:
# Index(['airline', 'avail_seat_km_per_week', 'incidents_85_99',
#        'fatal_accidents_85_99', 'fatalities_85_99', 'incidents_00_14',
#        'fatal_accidents_00_14', 'fatalities_00_14'],
#       dtype='object')

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   airline                 56 non-null     object
#  1   avail_seat_km_per_week  56 non-null     int64
#  2   incidents_85_99         56 non-null     int64
#  3   fatal_accidents_85_99   56 non-null     int64
#  4   fatalities_85_99        56 non-null     int64
#  5   incidents_00_14         56 non-null     int64
#  6   fatal_accidents_00_14   56 non-null     int64
#  7   fatalities_00_14        56 non-null     int64
# dtypes: int64(7), object(1)
# memory usage: 3.6+ KB

# %%
airlines.describe()
# Out:
#        avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  \
# count            5.600000e+01        56.000000              56.000000
# mean             1.384621e+09         7.178571               2.178571
# std              1.465317e+09        11.035656               2.861069
# min              2.593733e+08         0.000000               0.000000
# 25%              4.740362e+08         2.000000               0.000000
# 50%              8.029089e+08         4.000000               1.000000
# 75%              1.847239e+09         8.000000               3.000000
# max              7.139291e+09        76.000000              14.000000
#
#        fatalities_85_99  incidents_00_14  fatal_accidents_00_14  \
# count         56.000000        56.000000              56.000000
# mean         112.410714         4.125000               0.660714
# std          146.691114         4.544977               0.858684
# min            0.000000         0.000000               0.000000
# ...

# %%
airlines.describe(include='O')
# Out:
#            airline
# count           56
# unique          56
# top     Aer Lingus
# freq             1

# %%
airlines.airline.unique()
# Out:
# array(['Aer Lingus', 'Aeroflot*', 'Aerolineas Argentinas', 'Aeromexico*',
#        'Air Canada', 'Air France', 'Air India*', 'Air New Zealand*',
#        'Alaska Airlines*', 'Alitalia', 'All Nippon Airways', 'American*',
#        'Austrian Airlines', 'Avianca', 'British Airways*',
#        'Cathay Pacific*', 'China Airlines', 'Condor', 'COPA',
#        'Delta / Northwest*', 'Egyptair', 'El Al', 'Ethiopian Airlines',
#        'Finnair', 'Garuda Indonesia', 'Gulf Air', 'Hawaiian Airlines',
#        'Iberia', 'Japan Airlines', 'Kenya Airways', 'KLM*', 'Korean Air',
#        'LAN Airlines', 'Lufthansa*', 'Malaysia Airlines',
#        'Pakistan International', 'Philippine Airlines', 'Qantas*',
#        'Royal Air Maroc', 'SAS*', 'Saudi Arabian', 'Singapore Airlines',
#        'South African', 'Southwest Airlines', 'Sri Lankan / AirLanka',
#        'SWISS*', 'TACA', 'TAM', 'TAP - Air Portugal', 'Thai Airways',
#        'Turkish Airlines', 'United / Continental*',
# ...

# %%
airlines.value_counts('incidents_85_99')
# Out:
# incidents_85_99
# 2     9
# 3     8
# 1     7
# 7     5
# 8     5
# 5     4
# 0     3
# 4     2
# 6     2
# 12    2
# 19    1
# 25    1
# 24    1
# 21    1
# 9     1
# 16    1
# 14    1
# 10    1
# 76    1
# dtype: int64

# %%
airlines.value_counts('incidents_00_14')
# Out:
# incidents_00_14
# 0     9
# 1     9
# 2     8
# 5     6
# 3     5
# 4     5
# 6     4
# 7     2
# 8     2
# 11    2
# 10    1
# 14    1
# 17    1
# 24    1
# dtype: int64

# %%
airlines.value_counts('fatal_accidents_85_99')
# Out:
# fatal_accidents_85_99
# 0     17
# 1     16
# 3      8
# 2      4
# 4      3
# 5      3
# 6      1
# 7      1
# 8      1
# 12     1
# 14     1
# dtype: int64

# %%
airlines.value_counts('fatal_accidents_00_14')
# Out:
# fatal_accidents_00_14
# 0    32
# 1    12
# 2    11
# 3     1
# dtype: int64

# %%
airlines.value_counts('fatalities_85_99')
# Out:
# fatalities_85_99
# 0      17
# 3       2
# 64      2
# 282     1
# 167     1
# 171     1
# 224     1
# 229     1
# 234     1
# 260     1
# 308     1
# 148     1
# 313     1
# 319     1
# 323     1
# 329     1
# 407     1
# 425     1
# 520     1
# 159     1
# 128     1
# 1       1
# 34      1
# 2       1
# 4       1
# 6       1
# 14      1
# 16      1
# 21      1
# 47      1
# 101     1
# 50      1
# 51      1
# 74      1
# 79      1
# 82      1
# 98      1
# 535     1
# dtype: int64

# %%
airlines.value_counts('fatalities_00_14')
# Out:
# fatalities_00_14
# 0      32
# 1       2
# 88      2
# 7       1
# 14      1
# 416     1
# 337     1
# 283     1
# 225     1
# 188     1
# 158     1
# 143     1
# 110     1
# 109     1
# 92      1
# 3       1
# 84      1
# 83      1
# 51      1
# 46      1
# 23      1
# 22      1
# 537     1
# dtype: int64

# %%
airlines.columns
# Out:
# Index(['airline', 'avail_seat_km_per_week', 'incidents_85_99',
#        'fatal_accidents_85_99', 'fatalities_85_99', 'incidents_00_14',
#        'fatal_accidents_00_14', 'fatalities_00_14'],
#       dtype='object')

# %%
pd.pivot_table(airlines, values=['incidents_85_99','incidents_00_14'], index='airline', aggfunc=sum)
# Out:
#                             incidents_00_14  incidents_85_99
# airline
# Aer Lingus                                0                2
# Aeroflot*                                 6               76
# Aerolineas Argentinas                     1                6
# Aeromexico*                               5                3
# Air Canada                                2                2
# Air France                                6               14
# Air India*                                4                2
# Air New Zealand*                          5                3
# Alaska Airlines*                          5                5
# Alitalia                                  4                7
# All Nippon Airways                        7                3
# American*                                17               21
# Austrian Airlines                         1                1
# Avianca                                   0                5
# ...

# %%
plt.figure(figsize=(8,10))
sns.barplot(y='airline', x='incidents_85_99', data=airlines);

# %%
plt.figure(figsize=(8,10))
sns.barplot(y='airline', x='incidents_00_14', data=airlines);

# %%
pd.pivot_table(airlines, values=['fatal_accidents_85_99','fatal_accidents_00_14'], index='airline',aggfunc=sum)
# Out:
#                             fatal_accidents_00_14  fatal_accidents_85_99
# airline
# Aer Lingus                                      0                      0
# Aeroflot*                                       1                     14
# Aerolineas Argentinas                           0                      0
# Aeromexico*                                     0                      1
# Air Canada                                      0                      0
# Air France                                      2                      4
# Air India*                                      1                      1
# Air New Zealand*                                1                      0
# Alaska Airlines*                                1                      0
# Alitalia                                        0                      2
# All Nippon Airways                              0                      1
# American*                                       3                      5
# ...

# %%
plt.figure(figsize=(8,10))
sns.barplot(y='airline', x='fatal_accidents_85_99', data=airlines);

# %%
plt.figure(figsize=(8,10))
sns.barplot(y='airline', x='fatal_accidents_00_14', data=airlines);

# %%
pd.pivot_table(airlines, values=['fatalities_85_99','fatalities_00_14'], index='airline', aggfunc=sum)
# Out:
#                             fatalities_00_14  fatalities_85_99
# airline
# Aer Lingus                                 0                 0
# Aeroflot*                                 88               128
# Aerolineas Argentinas                      0                 0
# Aeromexico*                                0                64
# Air Canada                                 0                 0
# Air France                               337                79
# Air India*                               158               329
# Air New Zealand*                           7                 0
# Alaska Airlines*                          88                 0
# Alitalia                                   0                50
# All Nippon Airways                         0                 1
# American*                                416               101
# Austrian Airlines                          0                 0
# Avianca                                    0               323
# ...

# %%
air_india=airlines[airlines.airline=='Air India*']

# %%
air_india
# Out:
#       airline  avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  \
# 6  Air India*               869253552                2                      1
#
#    fatalities_85_99  incidents_00_14  fatal_accidents_00_14  fatalities_00_14
# 6               329                4                      1               158

# %%
air_india=airlines[airlines['airline']=='Air India*']

# %%
air_india
# Out:
#       airline  avail_seat_km_per_week  incidents_85_99  fatal_accidents_85_99  \
# 6  Air India*               869253552                2                      1
#
#    fatalities_85_99  incidents_00_14  fatal_accidents_00_14  fatalities_00_14
# 6               329                4                      1               158
